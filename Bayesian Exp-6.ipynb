# %%
import pandas as pd
from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.inference import VariableElimination
# !pip install pandas pgmpy

import pandas as pd
from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.inference import VariableElimination

data = pd.DataFrame({
    'Rain': ['No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No'],
    'TrafficJam': ['Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No'],
    'ArriveLate': ['Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No']
})

model = DiscreteBayesianNetwork([
    ('Rain', 'TrafficJam'),
    ('TrafficJam', 'ArriveLate')
])

model.fit(data)

inference = VariableElimination(model)
query_result = inference.query(variables=['ArriveLate'], evidence={'Rain': 'Yes'})
print(query_result.values)
data = pd.DataFrame({
    'Rain': ['No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No'],
    'TrafficJam': ['Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No'],
    'ArriveLate': ['Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No']
})

model = DiscreteBayesianNetwork([
    ('Rain', 'TrafficJam'),
    ('TrafficJam', 'ArriveLate')
])

model.fit(data)

for cpd in model.get_cpds():
    print(cpd)
    print()

inference = VariableElimination(model)
query_result = inference.query(variables=['ArriveLate'], evidence={'Rain': 'Yes'})
print(query_result)
# Out:
# Requirement already satisfied: pandas in c:\users\aimllab2\anaconda33\lib\site-packages (2.3.3)
# Requirement already satisfied: pgmpy in c:\users\aimllab2\anaconda33\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\aimllab2\anaconda33\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aimllab2\anaconda33\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aimllab2\anaconda33\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aimllab2\anaconda33\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: networkx in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (3.5)
# Requirement already satisfied: scipy in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (1.16.3)
# Requirement already satisfied: scikit-learn in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (1.8.0)
# Requirement already satisfied: torch in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (2.10.0)
# Requirement already satisfied: statsmodels in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (0.14.5)
# Requirement already satisfied: tqdm in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (4.67.1)
# Requirement already satisfied: joblib in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (1.5.2)
# Requirement already satisfied: opt-einsum in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (3.4.0)
# Requirement already satisfied: pyro-ppl in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (1.9.1)
# Requirement already satisfied: six>=1.5 in c:\users\aimllab2\anaconda33\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pyro-api>=0.1.1 in c:\users\aimllab2\anaconda33\lib\site-packages (from pyro-ppl->pgmpy) (0.1.2)
# Requirement already satisfied: filelock in c:\users\aimllab2\anaconda33\lib\site-packages (from torch->pgmpy) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\aimllab2\anaconda33\lib\site-packages (from torch->pgmpy) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\aimllab2\anaconda33\lib\site-packages (from torch->pgmpy) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\aimllab2\anaconda33\lib\site-packages (from torch->pgmpy) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\aimllab2\anaconda33\lib\site-packages (from torch->pgmpy) (2025.10.0)
# Requirement already satisfied: setuptools in c:\users\aimllab2\anaconda33\lib\site-packages (from torch->pgmpy) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aimllab2\anaconda33\lib\site-packages (from sympy>=1.13.3->torch->pgmpy) (1.3.0)
# Requirement already satisfied: colorama in c:\users\aimllab2\anaconda33\lib\site-packages (from tqdm->pgmpy) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aimllab2\anaconda33\lib\site-packages (from jinja2->torch->pgmpy) (3.0.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\aimllab2\anaconda33\lib\site-packages (from scikit-learn->pgmpy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\aimllab2\anaconda33\lib\site-packages (from statsmodels->pgmpy) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\aimllab2\anaconda33\lib\site-packages (from statsmodels->pgmpy) (25.0)
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'Rain': 'C', 'TrafficJam': 'C', 'ArriveLate': 'C'}
# INFO:pgmpy: Datatype (N=numerical, C=Categorical Unordered, O=Categorical Ordered) inferred from data:
#  {'Rain': 'C', 'TrafficJam': 'C', 'ArriveLate': 'C'}
# Requirement already satisfied: pandas in c:\users\aimllab2\anaconda33\lib\site-packages (2.3.3)
# Requirement already satisfied: pgmpy in c:\users\aimllab2\anaconda33\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\aimllab2\anaconda33\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aimllab2\anaconda33\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aimllab2\anaconda33\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aimllab2\anaconda33\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: networkx in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (3.5)
# Requirement already satisfied: scipy in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (1.16.3)
# Requirement already satisfied: scikit-learn in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (1.8.0)
# Requirement already satisfied: torch in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (2.10.0)
# Requirement already satisfied: statsmodels in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (0.14.5)
# Requirement already satisfied: tqdm in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (4.67.1)
# Requirement already satisfied: joblib in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (1.5.2)
# Requirement already satisfied: opt-einsum in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (3.4.0)
# Requirement already satisfied: pyro-ppl in c:\users\aimllab2\anaconda33\lib\site-packages (from pgmpy) (1.9.1)
# Requirement already satisfied: six>=1.5 in c:\users\aimllab2\anaconda33\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pyro-api>=0.1.1 in c:\users\aimllab2\anaconda33\lib\site-packages (from pyro-ppl->pgmpy) (0.1.2)
# Requirement already satisfied: filelock in c:\users\aimllab2\anaconda33\lib\site-packages (from torch->pgmpy) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\aimllab2\anaconda33\lib\site-packages (from torch->pgmpy) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\aimllab2\anaconda33\lib\site-packages (from torch->pgmpy) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\aimllab2\anaconda33\lib\site-packages (from torch->pgmpy) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\aimllab2\anaconda33\lib\site-packages (from torch->pgmpy) (2025.10.0)
# Requirement already satisfied: setuptools in c:\users\aimllab2\anaconda33\lib\site-packages (from torch->pgmpy) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aimllab2\anaconda33\lib\site-packages (from sympy>=1.13.3->torch->pgmpy) (1.3.0)
# Requirement already satisfied: colorama in c:\users\aimllab2\anaconda33\lib\site-packages (from tqdm->pgmpy) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aimllab2\anaconda33\lib\site-packages (from jinja2->torch->pgmpy) (3.0.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\aimllab2\anaconda33\lib\site-packages (from scikit-learn->pgmpy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\aimllab2\anaconda33\lib\site-packages (from statsmodels->pgmpy) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\aimllab2\anaconda33\lib\site-packages (from statsmodels->pgmpy) (25.0)
# [0.5 0.5]
# +-----------+-----+
# | Rain(No)  | 0.5 |
# +-----------+-----+
# | Rain(Yes) | 0.5 |
# +-----------+-----+
#
# +-----------------+----------+-----------+
# | Rain            | Rain(No) | Rain(Yes) |
# +-----------------+----------+-----------+
# | TrafficJam(No)  | 0.5      | 0.5       |
# +-----------------+----------+-----------+
# | TrafficJam(Yes) | 0.5      | 0.5       |
# +-----------------+----------+-----------+
#
# +-----------------+----------------+-----------------+
# | TrafficJam      | TrafficJam(No) | TrafficJam(Yes) |
# +-----------------+----------------+-----------------+
# | ArriveLate(No)  | 0.75           | 0.25            |
# +-----------------+----------------+-----------------+
# | ArriveLate(Yes) | 0.25           | 0.75            |
# +-----------------+----------------+-----------------+
#
# +-----------------+-------------------+
# | ArriveLate      |   phi(ArriveLate) |
# +=================+===================+
# | ArriveLate(No)  |            0.5000 |
# +-----------------+-------------------+
# | ArriveLate(Yes) |            0.5000 |
# +-----------------+-------------------+
